# %%
import os 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("numeric and cat dada.csv")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data["day"].nunique()
# Out:
# 4

# %%
data["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.countplot(x="sex",data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="day",data=data)
sns.despine() # no top and right axes spine

# %%
sns.countplot(x="smoker",data=data,hue="sex")
print(data.smoker.value_counts())
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.catplot(x="sex",data=data,kind="count")

# %%
sns.catplot(x="sex",data=data,hue="smoker",col="day",kind="count")

# %%
sns.catplot(x="sex",data=data,hue="smoker",row="day",kind="count")

# %%
sns.catplot(x="day",data=data,hue="smoker",col="sex",kind="count")

# %%
cc=data["sex"].value_counts(normalize=True)*100 #النسبة
sns.barplot(y=cc,x=cc.index,data=data)
print(cc)
# Out:
# Male      64.344262
# Female    35.655738
# Name: sex, dtype: float64

# %%
sns.catplot(data=data,x="total_bill",y="tip",hue="time")
plt.show()

# %%
sns.catplot(data=data,x="sex",y="tip",hue="time",height=5, aspect=.8)

# %%
sns.catplot(data=data,x="day",y="tip",hue="time",col="smoker",row="sex")

# %%
sns.boxplot(x='total_bill', data=data, color='red').set(title='Total_bill outliers')
# Out:
# [Text(0.5, 1.0, 'Total_bill outliers')]

# %%
sns.boxplot(x='tip', data=data).set_title('Tip outliers')
# Out:
# Text(0.5, 1.0, 'Tip outliers')

# %%
sns.histplot(data['day'],kde=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.swarmplot(y="tip",x="sex",data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.heatmap(data.corr(),annot=True,fmt=".2f",linewidths=1)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=data,x="sex",y="tip")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(data.tip)
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %%
sns.violinplot(data["total_bill"])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>
